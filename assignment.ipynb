# %% [markdown]
# # Assignment 8: Murder Mystery Agents
#
# Build detective agent workflows that solve two murder mysteries using the OpenAI Agents SDK. You'll use **prompt chaining** — the workflow pattern from the lecture — where each agent handles one stage of the investigation and passes structured results to the next.
#
# **What you'll do:** Each Agent is already defined with its name, model, tools, and output type — you write the `instructions` prompt that tells it what role to play, what to investigate, and how to reason about the evidence. That's it — **5 prompts across 4 TODOs**. Everything else is provided.
#
# ## Setup

# %%
# %pip install -q -r requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
# %reset -f

import os
import json
from dotenv import load_dotenv
from openai import AsyncOpenAI
from pydantic import BaseModel
from IPython.display import display, HTML
from agents import Agent, ModelSettings, Runner, function_tool, set_tracing_disabled
from agents.models.openai_chatcompletions import OpenAIChatCompletionsModel

load_dotenv()
os.makedirs("output", exist_ok=True)

# Same setup pattern as the demos: explicit model object + settings
set_tracing_disabled(True)

if os.environ.get("OPENROUTER_API_KEY"):
    client = AsyncOpenAI(
        api_key=os.environ["OPENROUTER_API_KEY"],
        base_url="https://openrouter.ai/api/v1",
    )
    AGENTS_MODEL = OpenAIChatCompletionsModel(model="openai/gpt-4o-mini", openai_client=client)
elif os.environ.get("OPENAI_API_KEY"):
    client = AsyncOpenAI(api_key=os.environ["OPENAI_API_KEY"])
    AGENTS_MODEL = OpenAIChatCompletionsModel(model="gpt-4o-mini", openai_client=client)
else:
    raise ValueError("Set OPENROUTER_API_KEY or OPENAI_API_KEY in .env")

SETTINGS = ModelSettings(temperature=0, max_tokens=4096)

print("Setup complete")
# Out:
# Setup complete

# %% [markdown]
# ## Display Helpers
#
# These functions render investigation output as styled HTML — evidence cards, chat bubbles, detective notes, and verdict panels. You don't need to modify these; they're called automatically by the tools and checkpoint cells.

# %%
from helpers import (
    case_briefing, display_stage, display_search, display_interrogation,
    display_notes, display_witness, display_verdict,
)

# %% [markdown]
# ## Transcript Logger
#
# Tracks what the detective agents do — which tools they call and what they learn. The transcript is saved with results for grading.

# %%
transcript = []

def log_action(action_type: str, detail: str):
    """Append an entry to the investigation transcript."""
    transcript.append({"action": action_type, "detail": detail})

# %% [markdown]
# ---
#
# # Part 1: Murder at the Mountain Cabin
#
# A group of old college friends reunited at a remote mountain cabin. By Saturday morning, the host — Marcus Reed — was found dead. The cabin is snowed in. The killer is among the guests.
#
# You'll build a **three-stage investigation workflow** using prompt chaining:
#
# 1. **Crime Scene Investigation** — An agent searches all locations and summarizes the evidence
# 2. **Suspect Interrogation** — An agent uses the evidence to conduct targeted interviews
# 3. **Final Deduction** — An agent analyzes everything and makes the accusation
#
# Each stage produces structured output (`output_type`) that feeds into the next — the same chaining pattern from Demo 3.

# %%
with open("mystery_data.json") as f:
    cabin_data = json.load(f)

case_briefing(
    title=cabin_data["title"],
    setting=cabin_data["setting"],
    victim_name=cabin_data["victim"]["name"],
    cause=cabin_data["victim"]["cause_of_death"],
    suspects=[c["name"] + " — " + c["role"] for c in cabin_data["characters"].values()],
    locations=[loc["name"] for loc in cabin_data["locations"].values()],
)
# Out:
#     <div style="background:linear-gradient(135deg,#1a1a2e,#16213e);color:#e0e0e0;padding:20px 24px;border-radius:10px;border-left:5px solid #c62828;font-family:Georgia,serif;margin:12px 0;box-shadow:0 2px 8px rgba(0,0,0,0.3)">
#         <div style="font-size:20px;font-weight:bold;color:#ff8a80;letter-spacing:0.5px">&#128373; Murder at the Mountain Cabin</div>
#         <div style="margin:10px 0;font-style:italic;color:#bbb;border-bottom:1px solid #333;padding-bottom:10px">A group of old college friends reunited for a weekend at a remote mountain cabin. By Saturday morning, host Marcus Reed was found dead in the living room — struck from behind with a heavy object. The cabin is snowed in; no one could have entered or l</div>
#         <div style="margin:8px 0"><b>Victim:</b> Marcus Reed &mdash; <span style="color:#ef9a9a">Blunt force trauma to the back of the head</span></div>
#         <div><b>Suspects:</b><ul style="margin:4px 0"><li>Diana Blackwood — Marcus's ex-girlfriend</li><li>Larry Hoffman — Marcus's college roommate</li><li>Tom Chen — The group's peacemaker</li><li>Sofia Reyes — The newcomer</li></ul></div>
#         <div style='margin-top:8px'><b>Locations:</b><ul style='margin:4px 0'><li>Living Room</li><li>Kitchen</li><li>Mudroom / Back Entry</li><li>Upstairs Hallway</li><li>Back Porch</li><li>Marcus's Bedroom</li></ul></div>
#     </div>

# %% [markdown]
# ### Part 1 Tools
#
# These tools let agents interact with the mystery world. `search_location` returns clues from a location. `interrogate` creates a temporary sub-agent for each suspect — the suspect has its own personality and secrets embedded in a system prompt, so it responds in character.

# %%
@function_tool
def search_location(location_id: str) -> str:
    """Search a location in the cabin for clues. Valid locations: living_room, kitchen, mudroom, upstairs_hallway, back_porch, marcus_bedroom"""
    location = cabin_data["locations"].get(location_id)
    if not location:
        return f"Unknown location '{location_id}'. Valid: {', '.join(cabin_data['locations'].keys())}"
    log_action("search", f"Searched {location['name']}")
    display_search(location["name"], location["clues"])
    result = f"**{location['name']}**: {location['description']}\n\nClues found:\n"
    for clue in location["clues"]:
        result += f"- {clue}\n"
    return result


@function_tool
async def interrogate(character_name: str, question: str) -> str:
    """Interrogate a suspect by name. Ask them a specific question. Valid names: diana, larry, tom, sofia"""
    key = character_name.lower().strip()
    character = cabin_data["characters"].get(key)
    if not character:
        return f"Unknown character '{character_name}'. Valid: {', '.join(cabin_data['characters'].keys())}"

    log_action("interrogate", f"Asked {character['name']}: {question[:80]}")

    system_prompt = f"""You are {character['name']}, {character['role']} in a murder investigation.

Personality: {character['personality']}
Background: {character['background']}
Your secret: {character['secret']}
Your alibi: {character['alibi']}

Things you know or observed:
{chr(10).join('- ' + k for k in character['knows'])}

Behavioral guidelines: {character['guardrails']}

Stay in character. Answer the detective's question based on your knowledge, personality, and secrets. Keep responses to 2-4 sentences. You may lie or deflect according to your behavioral guidelines."""

    suspect_agent = Agent(
        name=character["name"],
        model=AGENTS_MODEL,
        model_settings=SETTINGS,
        instructions=system_prompt,
    )
    result = await Runner.run(suspect_agent, question)
    response = result.final_output
    log_action("response", f"{character['name']}: {response[:100]}")
    display_interrogation(character["name"], question, response)
    return response

cabin_tools = [search_location, interrogate]
print(f"Tools ready: {[t.name for t in cabin_tools]}")
# Out:
# Tools ready: ['search_location', 'interrogate']

# %% [markdown]
# ### Interactive Detective
#
# Use this to manually explore the mystery — search locations and interrogate suspects yourself. This helps you understand what evidence exists before writing agent instructions, and lets you verify your agents found the right things.

# %%
interactive_detective = Agent(
    name="Interactive Detective",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions="You are assisting a human detective investigating the murder of Marcus Reed at a mountain cabin. The human will tell you who to interrogate or where to search. Use your tools to carry out their requests and report back what you find.",
    tools=cabin_tools,
)

async def investigate(prompt):
    """Quick helper: ask the detective to do something and see the result."""
    result = await Runner.run(interactive_detective, prompt)
    print(f"\n{result.final_output}\n")

# %% [markdown]
# Try it out — run these to explore the mystery before writing your agent instructions:

# %%
# await investigate("Search the living room")
# Out:
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Living Room</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>The antler trophy on the mantel has been wiped clean — no fingerprints at all, which is suspicious since Marcus handled it regularly</li><li style='margin:2px 0'>A small scuff mark on the hardwood floor near the fireplace, consistent with a brief struggle</li><li style='margin:2px 0'>Marcus's phone on the coffee table shows his last text at 10:28pm to an unknown number: 'I told you, it's mine now. Deal with it.'</li><li style='margin:2px 0'>A glass of whiskey on the side table, half-finished — only Marcus's fingerprints</li></ul>
#     </div>
# In the living room, I found several clues:
#
# 1. **Antler Trophy**: The trophy on the mantel has been wiped clean of fingerprints, which is suspicious since Marcus handled it regularly.
# 2. **Scuff Mark**: There is a small scuff mark on the hardwood floor near the fireplace, indicating a brief struggle may have occurred.
# 3. **Marcus's Phone**: His phone is on the coffee table, showing a last text sent at 10:28 PM to an unknown number that reads: "I told you, it's mine now. Deal with it."
# 4. **Glass of Whiskey**: A half-finished glass of whiskey on the side table contains only Marcus's fingerprints.
#
# What would you like to do next?

# %%
# await investigate("Ask Larry about his alibi")
# Out:
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Larry Hoffman</i></div>
#                 What is your alibi for the time of Marcus Reed's murder?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129406; <b>Larry Hoffman</b></div>
#                 Oh, right! So, I was actually playing cards with Tom at our place until about 9:30 PM, and then I went to bed right after that. I mean, I was really tired, you know? I slept straight through the night and didn’t hear anything unusual at all. Just a normal night for me!
#             </div>
#         </div>
#     </div>
# Larry claims that he was playing cards with Tom at their place until about 9:30 PM and then went to bed right after that. He insists he was really tired and slept straight through the night without hearing anything unusual.
#
# Would you like to ask Tom about his alibi or search a specific location in the cabin for clues?

# %% [markdown]
# ### Part 1 Structured Outputs
#
# Each stage of the investigation produces structured data that feeds into the next. The `output_type` parameter forces each agent to return a Pydantic model instead of free text.

# %%
class EvidenceSummary(BaseModel):
    """Stage 1 output: what the crime scene investigation found."""
    clues: list[str]
    suspicious_items: list[str]
    key_questions: list[str]

class InterviewFindings(BaseModel):
    """Stage 2 output: what the interrogations revealed."""
    alibis: list[str]
    contradictions: list[str]
    key_observations: list[str]

class Accusation(BaseModel):
    """Stage 3 output: the final accusation."""
    killer: str
    weapon: str
    motive: str
    evidence: list[str]

# %% [markdown]
# ### TODO 1: Stage 1 — Crime Scene Investigation
#
# Write `instructions` for an agent that searches all six locations and summarizes the evidence. Your instructions should tell the agent its role, list all six location IDs to search, and ask it to summarize what it finds.
#
# **Location IDs:** `living_room`, `kitchen`, `mudroom`, `upstairs_hallway`, `back_porch`, `marcus_bedroom`

# %%
display_stage(1, "Crime Scene Investigation", "Searching all locations for physical evidence and clues")
transcript = []  # Reset transcript for Part 1

search_agent = Agent(
    name="Crime Scene Investigator",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions="""You are an experienced crime scene investigator examining a mountain cabin where Marcus Reed was found murdered. Your job is to systematically search every location in the cabin and document all evidence you find.

Search ALL six locations in this exact order using the search_location tool:
1. living_room
2. kitchen
3. mudroom
4. upstairs_hallway
5. back_porch
6. marcus_bedroom

After searching all six locations, compile your findings into a structured summary:
- clues: List every individual clue you found across all locations.
- suspicious_items: Items that seem out of place, tampered with, or directly connected to the murder.
- key_questions: Questions raised by the evidence that should be asked to suspects during interrogation. Focus on contradictions, unexplained items, and anything that could reveal motive or opportunity.

Be thorough. Do not skip any location. Every detail matters.""",  # TODO: Write your instructions here
    tools=[search_location],
    output_type=EvidenceSummary,
)

# Uncomment to run your agent:
search_result = await Runner.run(search_agent, "Search all six locations in the cabin for evidence.", max_turns=15)
evidence = search_result.final_output
# Out:
#     <div style="background:linear-gradient(90deg,#0d47a1,#1565c0,#1976d2);color:white;padding:12px 20px;border-radius:8px;margin:16px 0 8px 0;font-family:sans-serif;box-shadow:0 2px 6px rgba(0,0,0,0.2)">
#         <span style="background:rgba(255,255,255,0.2);padding:2px 10px;border-radius:12px;font-size:12px;font-weight:bold;margin-right:10px">STAGE 1</span>
#         <span style="font-size:16px;font-weight:bold">Crime Scene Investigation</span>
#         <div style="color:#b0bec5;font-size:13px;margin-top:4px">Searching all locations for physical evidence and clues</div>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Mudroom / Back Entry</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>Larry's hiking boots are damp and have fresh mud on them, though he claims he didn't go outside after dinner</li><li style='margin:2px 0'>A pair of rubber gloves from the cleaning supplies has been moved — one is inside-out as if hastily removed</li><li style='margin:2px 0'>Boot prints in the mud outside lead from the back porch around to the side of the cabin and back</li></ul>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Kitchen</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>Two coffee mugs on the counter from a late-night conversation — Diana's lipstick on one</li><li style='margin:2px 0'>A notepad by the phone with Marcus's handwriting: 'Larry — grandfather's map — told him NO'</li><li style='margin:2px 0'>The back door was unlocked, though everyone claims it was locked after dinner</li><li style='margin:2px 0'>A kitchen knife is missing from the block, but found later in the dishwasher (red herring — just from dinner prep)</li></ul>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Living Room</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>The antler trophy on the mantel has been wiped clean — no fingerprints at all, which is suspicious since Marcus handled it regularly</li><li style='margin:2px 0'>A small scuff mark on the hardwood floor near the fireplace, consistent with a brief struggle</li><li style='margin:2px 0'>Marcus's phone on the coffee table shows his last text at 10:28pm to an unknown number: 'I told you, it's mine now. Deal with it.'</li><li style='margin:2px 0'>A glass of whiskey on the side table, half-finished — only Marcus's fingerprints</li></ul>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Upstairs Hallway</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>A small smear on the hallway carpet near Larry's room — could be mud or something darker</li><li style='margin:2px 0'>Diana's door was heard opening and closing around 11pm by Tom</li><li style='margin:2px 0'>The bathroom shared by Larry and Tom's rooms has a freshly used hand towel with faint brown stains</li></ul>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Back Porch</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>Sofia's camera is mounted on a tripod aimed at the tree line — EXIF data confirms photos from 9:04pm to 11:27pm</li><li style='margin:2px 0'>From this vantage point, you can see directly into the living room through the large windows</li><li style='margin:2px 0'>Fresh boot prints in the snow lead from the porch steps around the side of the cabin</li><li style='margin:2px 0'>A cigarette butt near the railing — no one in the group claims to smoke (actually Marcus's — he hid it from the group)</li></ul>
#     </div>
#     <div style="background:#263238;color:#e0e0e0;padding:12px 16px;border-radius:8px;border-left:4px solid #ffd54f;margin:6px 0;font-family:'Courier New',monospace;font-size:13px">
#         <div style="font-size:14px;margin-bottom:6px">&#128269; <b style="color:#ffd54f">Marcus's Bedroom</b></div>
#         <ul style="margin:0;padding-left:20px;color:#cfd8dc"><li style='margin:2px 0'>Marcus's laptop is open on his desk, showing a real estate listing for the cabin — listed 3 days ago</li><li style='margin:2px 0'>A locked desk drawer contains old photographs from college, including one of Larry's grandfather's antique shop</li><li style='margin:2px 0'>An old hand-drawn map is tucked inside a book on the shelf — it looks like a treasure map with markings in a different handwriting than Marcus's</li><li style='margin:2px 0'>A journal entry from last week reads: 'Larry's been asking questions. He can't prove anything. The map led me to $200K in old coins — that was MY discovery.'</li></ul>
#     </div>

# %%
# Checkpoint: see what your agent found (uncomment after running TODO 1)
display_notes("Crime Scene Summary", {
    f"Clues found ({len(evidence.clues)})": evidence.clues,
    "Suspicious items": evidence.suspicious_items,
    "Questions to investigate": evidence.key_questions,
})
# Out:
#     <div style="background:#1a237e;color:#e0e0e0;padding:14px 18px;border-radius:8px;border-left:4px solid #42a5f5;margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:14px;font-weight:bold;color:#90caf9;margin-bottom:6px">&#128221; Crime Scene Summary</div>
#         <div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Clues found (22):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>The antler trophy on the mantel has been wiped clean — no fingerprints at all, which is suspicious since Marcus handled it regularly</li><li>A small scuff mark on the hardwood floor near the fireplace, consistent with a brief struggle</li><li>Marcus's phone on the coffee table shows his last text at 10:28pm to an unknown number: 'I told you, it's mine now. Deal with it.'</li><li>A glass of whiskey on the side table, half-finished — only Marcus's fingerprints</li><li>Two coffee mugs on the counter from a late-night conversation — Diana's lipstick on one</li><li>A notepad by the phone with Marcus's handwriting: 'Larry — grandfather's map — told him NO'</li><li>The back door was unlocked, though everyone claims it was locked after dinner</li><li>A kitchen knife is missing from the block, but found later in the dishwasher (red herring — just from dinner prep)</li><li>Larry's hiking boots are damp and have fresh mud on them, though he claims he didn't go outside after dinner</li><li>A pair of rubber gloves from the cleaning supplies has been moved — one is inside-out as if hastily removed</li><li>Boot prints in the mud outside lead from the back porch around to the side of the cabin and back</li><li>A small smear on the hallway carpet near Larry's room — could be mud or something darker</li><li>Diana's door was heard opening and closing around 11pm by Tom</li><li>The bathroom shared by Larry and Tom's rooms has a freshly used hand towel with faint brown stains</li><li>Sofia's camera is mounted on a tripod aimed at the tree line — EXIF data confirms photos from 9:04pm to 11:27pm</li><li>From this vantage point, you can see directly into the living room through the large windows</li><li>Fresh boot prints in the snow lead from the porch steps around the side of the cabin</li><li>A cigarette butt near the railing — no one in the group claims to smoke (actually Marcus's — he hid it from the group)</li><li>Marcus's laptop is open on his desk, showing a real estate listing for the cabin — listed 3 days ago</li><li>A locked desk drawer contains old photographs from college, including one of Larry's grandfather's antique shop</li><li>An old hand-drawn map is tucked inside a book on the shelf — it looks like a treasure map with markings in a different handwriting than Marcus's</li><li>A journal entry from last week reads: 'Larry's been asking questions. He can't prove anything. The map led me to $200K in old coins — that was MY discovery.'</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Suspicious items:</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>The antler trophy wiped clean of fingerprints</li><li>The unlocked back door</li><li>Larry's damp hiking boots with fresh mud</li><li>The inside-out rubber glove</li><li>The cigarette butt hidden by Marcus</li><li>The locked desk drawer in Marcus's bedroom</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Questions to investigate:</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>Why was the antler trophy wiped clean?</li><li>What was the content of Marcus's last text message? Who was the unknown recipient?</li><li>Why were the coffee mugs left out, and what was the nature of the conversation between Marcus and Diana?</li><li>Why was the back door unlocked when everyone claimed it was locked?</li><li>What is the significance of the notepad note about Larry and the grandfather's map?</li><li>Why do Larry's boots have fresh mud on them if he claims he didn't go outside?</li><li>What is the meaning of the smear found in the upstairs hallway?</li><li>What was Diana doing opening and closing her door around 11pm?</li><li>What do the brown stains on the hand towel indicate?</li><li>What was the purpose of Sofia's camera being set up to capture the living room?</li><l ...
#     </div>

# %% [markdown]
# **Checkpoint:** You should see 6 search cards (one per location) and 10+ clues. If the agent missed locations, make your instructions more explicit. Use `await investigate("Search the kitchen")` above to manually verify what's in each location.
#
# ### TODO 2: Stage 2 — Suspect Interrogation
#
# Write `instructions` for an agent that uses the evidence from Stage 1 to interrogate suspects. The key pattern: **embed Stage 1's output in Stage 2's instructions** — this is how results flow between agents in a chain.
#
# The `evidence_brief` below formats Stage 1's structured output as text. Your instructions should include it (via f-string) so the interrogator knows what to ask about.

# %%
display_stage(2, "Suspect Interrogation", "Questioning suspects based on crime scene evidence")

# This formats Stage 1 output as text for the interrogator's instructions
evidence_brief = f"""Evidence found so far:
Clues: {chr(10).join('- ' + c for c in evidence.clues)}
Suspicious items: {', '.join(evidence.suspicious_items)}
Key questions: {chr(10).join('- ' + q for q in evidence.key_questions)}"""

interview_agent = Agent(
    name="Lead Interrogator",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions=f"""You are a lead detective interrogating suspects in the murder of Marcus Reed at a remote mountain cabin. Your goal is to find contradictions between suspects' alibis and the physical evidence.

{evidence_brief}

Interrogate ALL four suspects: diana, larry, tom, sofia. For each suspect:
1. Ask about their alibi — where they were and what they were doing the night of the murder.
2. Confront them with any suspicious physical evidence that relates to them (muddy boots, fingerprints, moved objects, etc.).
3. Ask follow-up questions if their answers seem evasive, vague, or contradict the physical evidence.

Pay special attention to:
- Alibis that conflict with physical clues (e.g., someone claims they stayed inside but muddy boots were found)
- Items that were wiped clean or moved — this suggests someone is covering their tracks
- Defensive or deflecting behavior when confronted with evidence

After all interrogations, summarize:
- alibis: Each suspect's claimed alibi
- contradictions: Any places where a suspect's story conflicts with physical evidence or another suspect's account
- key_observations: Notable behaviors, evasions, or revealing statements""",  # TODO: Add your interrogation strategy around the evidence_brief above
    tools=[interrogate],
    output_type=InterviewFindings,
)

# Uncomment to run your agent:
interview_result = await Runner.run(interview_agent, "Interrogate all four suspects.", max_turns=25)
findings = interview_result.final_output
# Out:
#     <div style="background:linear-gradient(90deg,#0d47a1,#1565c0,#1976d2);color:white;padding:12px 20px;border-radius:8px;margin:16px 0 8px 0;font-family:sans-serif;box-shadow:0 2px 6px rgba(0,0,0,0.2)">
#         <span style="background:rgba(255,255,255,0.2);padding:2px 10px;border-radius:12px;font-size:12px;font-weight:bold;margin-right:10px">STAGE 2</span>
#         <span style="font-size:16px;font-weight:bold">Suspect Interrogation</span>
#         <div style="color:#b0bec5;font-size:13px;margin-top:4px">Questioning suspects based on crime scene evidence</div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Larry Hoffman</i></div>
#                 What is your alibi for the night of Marcus's murder? Where were you and what were you doing?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129406; <b>Larry Hoffman</b></div>
#                 Oh, right! My alibi, yes. I was actually playing cards with Tom at his place. We were just having a friendly game, you know, nothing too serious. I went to bed around 9:30pm and slept straight through the night. I didn't hear anything unusual at all! Just a normal night, really.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Sofia Reyes</i></div>
#                 What is your alibi for the night of Marcus's murder? Where were you and what were you doing?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128247; <b>Sofia Reyes</b></div>
#                 I was outside on the back porch taking long-exposure photos of the snowfall. I started around 9pm and stayed out there until about 11:30pm. My camera has timestamps that can confirm that. I prefer to be alone with my photography, so I didn't really pay much attention to what was happening inside the cabin.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Diana Blackwood</i></div>
#                 What is your alibi for the night of Marcus's murder? Where were you and what were you doing?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128131; <b>Diana Blackwood</b></div>
#                 I was in my room reading until midnight, then I slept through until 7am. I had no reason to leave my room, especially with the tension in the air. It's quite absurd to think I would have any involvement in this tragic situation.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Tom Chen</i></div>
#                 What is your alibi for the night of Marcus's murder? Where were you and what were you doing?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129658; <b>Tom Chen</b></div>
#                 I was playing cards with Larry until about 9:15 PM, and then I video-called my wife from my room. The call lasted from 9:20 PM to 10:45 PM, so I was on the phone during the time when I heard the raised voices downstairs. I really hope we can find out what happened to Marcus; he meant a lot to all of us.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Diana Blackwood</i></div>
#                 We found a glass of whiskey with only Marcus's fingerprints on it. Why would you leave it there if you were having a conversation with him?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128131; <b>Diana Blackwood</b></div>
#                 I wasn't having a conversation with him, Detective. I was in my room reading, as I stated. If Marcus had a drink, it was his choice to leave it behind. I can't speak to his habits, but I certainly wouldn't have touched his glass.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Sofia Reyes</i></div>
#                 Your camera was set up to capture the living room. Why were you photographing the inside of the cabin instead of the beautiful scenery outside?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128247; <b>Sofia Reyes</b></div>
#                 I wasn't actually photographing the inside of the cabin. I was focused on the snowfall and the way the light reflects off the snow at night. I just happened to be near the windows when I was taking my long-exposure shots. The scenery outside is beautiful, but I find the play of light and shadow in the snow really captivating.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Larry Hoffman</i></div>
#                 Your hiking boots were found muddy and damp, but you claimed you didn't go outside after dinner. Can you explain that?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129406; <b>Larry Hoffman</b></div>
#                 Oh, uh, those boots! You know how it is—sometimes I just forget to clean them after a hike. I might have stepped outside briefly to grab something from my car or, um, check the mail? I definitely didn’t go far, though. I was mostly just hanging out inside, playing cards with Tom and then went to bed early.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Tom Chen</i></div>
#                 You mentioned you were on a video call during the time of the murder. Can you provide any details about that call? Did you notice anything unusual during your conversation?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129658; <b>Tom Chen</b></div>
#                 Yes, I was on a video call with my wife from 9:20pm to 10:45pm, and I can confirm that the call lasted the entire time. We were discussing our kids and some upcoming plans, so nothing unusual there. However, I did hear some raised voices coming from downstairs around 10:30pm, which I mentioned to her, saying it sounded like Marcus was at it again. It was a bit concerning, but I didn't think much of it at the time.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Diana Blackwood</i></div>
#                 You mentioned you were reading in your room. Did you hear anything unusual, like raised voices or any commotion from the living room?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128131; <b>Diana Blackwood</b></div>
#                 I was quite engrossed in my book, so I can't say I heard anything out of the ordinary. However, I did catch a snippet of a heated argument between Larry and Marcus around 9pm. It seemed to be about something personal, but I didn't pay much attention to it—just typical male drama, I suppose.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Larry Hoffman</i></div>
#                 You said you might have stepped outside briefly. Can you clarify what you went outside for, and why your boots were muddy if you were only outside for a moment?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129406; <b>Larry Hoffman</b></div>
#                 Oh, uh, right! I mean, I might have stepped outside to get some fresh air, you know? Just a little breather after playing cards. The muddy boots? Well, it was raining earlier, and I guess I just didn't notice how muddy it was. I mean, who pays attention to their shoes when they're just trying to clear their head, right?
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Tom Chen</i></div>
#                 You heard raised voices around 10:30pm. Can you recall who was involved in the argument? Did you recognize any specific voices?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#129658; <b>Tom Chen</b></div>
#                 I couldn't make out specific voices, but it sounded like Marcus was involved, as he often had a way of raising his voice when he was passionate about something. I remember thinking it was typical of him to get into a heated discussion, especially if it was about something that mattered to him. I really hoped it wouldn't escalate, but I didn't want to interrupt my call with my wife.
#             </div>
#         </div>
#     </div>
#     <div style="margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="display:flex;align-items:flex-start;margin-bottom:4px">
#             <div style="background:#1b5e20;color:#e8f5e9;padding:8px 14px;border-radius:14px 14px 14px 2px;max-width:85%">
#                 <div style="font-size:11px;color:#a5d6a7;margin-bottom:2px">&#128373; <b>Detective</b> &rarr; <i>Sofia Reyes</i></div>
#                 You said you were focused on the snowfall. Did you notice anyone moving around inside the cabin while you were taking photos?
#             </div>
#         </div>
#         <div style="display:flex;justify-content:flex-end">
#             <div style="background:#37474f;color:#eceff1;padding:8px 14px;border-radius:14px 14px 2px 14px;max-width:85%">
#                 <div style="font-size:11px;color:#90a4ae;margin-bottom:2px">&#128247; <b>Sofia Reyes</b></div>
#                 I was pretty focused on my camera and the snowfall, so I didn't pay much attention to what was happening inside. I did hear a loud thud around 10:35, but I just assumed someone dropped something. I was mostly just trying to get the right exposure for the night shots.
#             </div>
#         </div>
#     </div>

# %%
# Checkpoint: see what your interrogator found (uncomment after running TODO 2)
display_notes("Interrogation Summary", {
    "Alibis": findings.alibis,
    "Contradictions": findings.contradictions,
    "Key observations": findings.key_observations,
})
# Out:
#     <div style="background:#1a237e;color:#e0e0e0;padding:14px 18px;border-radius:8px;border-left:4px solid #42a5f5;margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:14px;font-weight:bold;color:#90caf9;margin-bottom:6px">&#128221; Interrogation Summary</div>
#         <div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Alibis:</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>I was in my room reading until midnight, then I slept through until 7am. I had no reason to leave my room, especially with the tension in the air.</li><li>I was actually playing cards with Tom at his place. We were just having a friendly game, you know, nothing too serious. I went to bed around 9:30pm and slept straight through the night.</li><li>I was playing cards with Larry until about 9:15 PM, and then I video-called my wife from my room. The call lasted from 9:20 PM to 10:45 PM, so I was on the phone during the time when I heard the raised voices downstairs.</li><li>I was outside on the back porch taking long-exposure photos of the snowfall. I started around 9pm and stayed out there until about 11:30pm.</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Contradictions:</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>Diana claims she was reading in her room and didn't hear anything unusual, yet she mentioned a heated argument between Larry and Marcus around 9pm, which contradicts her earlier statement of not hearing anything.</li><li>Larry's muddy boots contradict his claim of not going outside after dinner. He suggested he might have stepped outside briefly, but the condition of his boots suggests he was outside longer or in a muddy area.</li><li>Tom claims he was on a video call during the time of the murder, but he heard raised voices around 10:30pm, which raises questions about the timing and nature of the call.</li><li>Sofia's focus on the snowfall outside contradicts her claim of not noticing anyone moving inside the cabin, especially since she was photographing the area near the windows.</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Key observations:</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>Diana's evasiveness about the whiskey glass suggests she may be hiding something about her interaction with Marcus.</li><li>Larry's inconsistent explanation for his muddy boots raises suspicion about his activities that night.</li><li>Tom's mention of raised voices during his call indicates he may have been aware of the situation inside the cabin, contradicting his earlier claim of being unaware of any issues.</li><li>Sofia's focus on the snowfall and her mention of a loud thud around 10:35 could indicate she was more aware of the cabin's interior than she admits.</li></ul></div>
#     </div>

# %% [markdown]
# **Checkpoint:** You should see chat bubbles for each suspect and at least one contradiction in the findings. If `contradictions` is empty, your instructions need to tell the agent to follow up when answers seem evasive or contradict physical evidence. Use `await investigate("Ask Larry about his muddy boots")` to manually explore what suspects say.
#
# ### TODO 3: Stage 3 — Final Deduction
#
# Write `instructions` for an agent that analyzes ALL evidence and makes the final accusation. This agent has **no tools** — it just reasons over the `case_file` built from Stages 1 and 2.

# %%
display_stage(3, "Final Deduction", "Analyzing all evidence to identify the killer")

# This combines all evidence for the deduction agent
case_file = f"""{evidence_brief}

Interview findings:
Alibis: {chr(10).join('- ' + a for a in findings.alibis)}
Contradictions: {chr(10).join('- ' + c for c in findings.contradictions)}
Key observations: {chr(10).join('- ' + o for o in findings.key_observations)}"""

deduction_agent = Agent(
    name="Lead Detective",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions="""You are the lead detective making the final accusation in the murder of Marcus Reed. You must analyze ALL the evidence — physical clues, suspect alibis, contradictions, and observations — to identify the killer, the weapon, and the motive.

Follow this reasoning process:
1. Review each suspect's alibi carefully.
2. Compare each alibi against the physical evidence. Physical evidence does NOT lie — muddy boots, wiped fingerprints, moved objects, and other tangible clues are facts. If a suspect's alibi is contradicted by physical evidence, they are lying.
3. Identify which suspect's alibi is MOST clearly contradicted by the physical evidence — that person is the killer.
4. Determine the murder weapon based on the physical evidence found at or near the crime scene and the cause of death.
5. Determine the motive from what you learned during interrogation and from the evidence.

Your accusation must include:
- killer: The full name of the murderer
- weapon: The specific weapon used
- motive: Why they killed Marcus Reed
- evidence: The key pieces of evidence that prove their guilt

Be specific and ground every part of your accusation in concrete evidence.""",  # TODO: Write your instructions here
    output_type=Accusation,
)

# Uncomment to run your agent:
deduction_result = await Runner.run(deduction_agent, f"Based on all evidence, make your accusation:\n\n{case_file}", max_turns=3)
accusation = deduction_result.final_output
# Out:
#     <div style="background:linear-gradient(90deg,#0d47a1,#1565c0,#1976d2);color:white;padding:12px 20px;border-radius:8px;margin:16px 0 8px 0;font-family:sans-serif;box-shadow:0 2px 6px rgba(0,0,0,0.2)">
#         <span style="background:rgba(255,255,255,0.2);padding:2px 10px;border-radius:12px;font-size:12px;font-weight:bold;margin-right:10px">STAGE 3</span>
#         <span style="font-size:16px;font-weight:bold">Final Deduction</span>
#         <div style="color:#b0bec5;font-size:13px;margin-top:4px">Analyzing all evidence to identify the killer</div>
#     </div>

# %%
# Uncomment to see the verdict:
display_verdict("ACCUSATION", {
    "Killer": accusation.killer,
    "Weapon": accusation.weapon,
    "Motive": accusation.motive,
    "Evidence": ", ".join(accusation.evidence),
})
# Out:
#     <div style="background:linear-gradient(135deg,#1a1a2e,#0d1117);color:#e0e0e0;padding:20px 24px;border-radius:10px;border-left:5px solid #c62828;font-family:Georgia,serif;margin:16px 0;box-shadow:0 2px 8px rgba(0,0,0,0.3)">
#         <div style="font-size:18px;font-weight:bold;color:#ff8a80;margin-bottom:10px;letter-spacing:1px">&#9878; ACCUSATION</div>
#         <table style="border-collapse:collapse"><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Killer</td><td style='padding:6px 14px;color:#e0e0e0'>Larry Johnson</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Weapon</td><td style='padding:6px 14px;color:#e0e0e0'>Antler trophy</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Motive</td><td style='padding:6px 14px;color:#e0e0e0'>Jealousy over Marcus's discovery of valuable coins and the potential sale of the cabin</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Evidence</td><td style='padding:6px 14px;color:#e0e0e0'>The antler trophy was wiped clean of fingerprints, indicating it was used as a weapon and the killer attempted to conceal their identity., Larry's hiking boots were found muddy and damp, contradicting his claim of not going outside after dinner, suggesting he was outside during the time of the murder., Marcus's last text message indicated a confrontation over ownership of something valuable, which aligns with Larry's motive to eliminate Marcus to gain control over the discovery of the coins., The unlocked back door suggests someone entered or exited the cabin without the others knowing, likely Larry after the murder., Diana's contradictory statements about hearing raised voices and her evasiveness regarding the whiskey glass suggest she was aware of the tension between Marcus and Larry.</td></tr></table>
#     </div>

# %% [markdown]
# **Checkpoint:** If the accusation is wrong, the deduction agent can only reason about what's in `case_file`. Print it (`print(case_file)`) to see if the evidence and contradictions are specific enough. If not, go back and improve your Stage 2 instructions. This iterative refinement is how real agent development works.
#
# **Hint:** Your instructions should tell the agent to compare each suspect's alibi against the physical evidence — physical evidence doesn't lie (muddy boots, wiped fingerprints, moved objects). The suspect whose alibi is most clearly contradicted is the killer.
#
# ### Save Part 1 Results

# %%
part1_results = {
    "killer": accusation.killer,
    "weapon": accusation.weapon,
    "motive": accusation.motive,
    "evidence": accusation.evidence,
    "transcript": transcript,
}

with open("output/part1_results.json", "w") as f:
    json.dump(part1_results, f, indent=2)

print(f"Saved to output/part1_results.json ({len(transcript)} transcript entries)")
# Out:
# Saved to output/part1_results.json (30 transcript entries)

# %% [markdown]
# ---
#
# # Part 2: Death at St. Mercy Hospital
#
# A structured logic puzzle. Dr. Eleanor Voss was found dead in her office. Security footage shows no one entered or left overnight — the killer was already inside. Use deduction tools to analyze evidence and identify the killer, weapon, and time of death.

# %%
with open("mystery_o_matic.json") as f:
    hospital_data = json.load(f)

case_briefing(
    title=hospital_data["title"],
    setting=hospital_data["setting"],
    victim_name=hospital_data["victim"]["name"],
    cause=hospital_data["victim"]["cause_of_death"],
    suspects=[s["name"] + " — " + s["role"] for s in hospital_data["suspects"].values()],
)
# Out:
#     <div style="background:linear-gradient(135deg,#1a1a2e,#16213e);color:#e0e0e0;padding:20px 24px;border-radius:10px;border-left:5px solid #c62828;font-family:Georgia,serif;margin:12px 0;box-shadow:0 2px 8px rgba(0,0,0,0.3)">
#         <div style="font-size:20px;font-weight:bold;color:#ff8a80;letter-spacing:0.5px">&#128373; Death at St. Mercy Hospital</div>
#         <div style="margin:10px 0;font-style:italic;color:#bbb;border-bottom:1px solid #333;padding-bottom:10px">Dr. Eleanor Voss, chief of cardiology at St. Mercy Hospital, was found dead in her office Monday morning. She was last seen alive at 8:00 PM Sunday evening during her overnight shift. Security footage shows no one entering or leaving the building bet</div>
#         <div style="margin:8px 0"><b>Victim:</b> Dr. Eleanor Voss &mdash; <span style="color:#ef9a9a">Lethal injection of potassium chloride</span></div>
#         <div><b>Suspects:</b><ul style="margin:4px 0"><li>Dr. Raymond Blake — Cardiologist, Dr. Voss's protégé</li><li>Nurse Margaret Chen — Senior ICU Nurse</li><li>Dr. Maria Santos — Emergency Medicine physician</li><li>Victor James — Night orderly</li></ul></div>
#
#     </div>

# %% [markdown]
# ### Part 2 Tools
#
# Deduction tools that give the agent access to different categories of evidence. Unlike Part 1, there are no interactive sub-agents — just data retrieval tools.

# %%
@function_tool
def get_room_map() -> str:
    """Get the hospital floor map showing all rooms and their locations."""
    log_action("tool", "Retrieved room map")
    result = "Hospital Floor Map:\n"
    for floor, rooms in hospital_data["rooms"].items():
        result += f"\n{floor.replace('_', ' ').title()}: {', '.join(rooms)}"
    return result


@function_tool
def get_witness_statement(suspect: str) -> str:
    """Get a suspect's statement and background. Valid suspects: dr_blake, nurse_chen, dr_santos, orderly_james"""
    key = suspect.lower().strip().replace(" ", "_").replace("dr.", "dr").replace("dr ", "dr_")
    suspect_data = hospital_data["suspects"].get(key)
    if not suspect_data:
        return f"Unknown suspect '{suspect}'. Valid: {', '.join(hospital_data['suspects'].keys())}"
    log_action("interview", f"Got statement from {suspect_data['name']}")
    display_witness(suspect_data['name'], suspect_data['role'], suspect_data['statement'])
    return f"""**{suspect_data['name']}** ({suspect_data['role']})
Motive: {suspect_data['motive']}
Statement: "{suspect_data['statement']}" """


@function_tool
def get_evidence() -> str:
    """Get all physical evidence and keycard logs from the investigation."""
    log_action("tool", "Retrieved evidence and keycard logs")
    result = "=== KEYCARD ACCESS LOGS ===\n"
    for entry in hospital_data["evidence"]["keycard_logs"]:
        result += f"{entry['time']} | {entry['person']} | {entry['location']} ({entry['action']})\n"
    result += "\n=== PHYSICAL EVIDENCE ===\n"
    for item in hospital_data["evidence"]["physical_evidence"]:
        result += f"- {item}\n"
    result += "\n=== WITNESS OBSERVATIONS ===\n"
    for obs in hospital_data["evidence"]["witness_statements"]:
        result += f"- {obs['witness']}: {obs['statement']}\n"
    return result


@function_tool
def get_weapons() -> str:
    """Get information about potential murder weapons found or available in the hospital."""
    log_action("tool", "Retrieved weapons analysis")
    result = "=== WEAPONS ANALYSIS ===\n"
    for weapon_id, weapon in hospital_data["weapons"].items():
        result += f"\n**{weapon_id.replace('_', ' ').title()}**: {weapon['description']}\n"
        result += f"  Availability: {weapon['availability']}\n"
        result += f"  Notes: {weapon['notes']}\n"
    return result


@function_tool
def get_rules() -> str:
    """Get the logical rules and constraints for solving this mystery."""
    log_action("tool", "Retrieved investigation rules")
    result = "=== INVESTIGATION RULES ===\n"
    for i, rule in enumerate(hospital_data["rules"], 1):
        result += f"{i}. {rule}\n"
    return result

hospital_tools = [get_room_map, get_witness_statement, get_evidence, get_weapons, get_rules]
print(f"Tools ready: {[t.name for t in hospital_tools]}")
# Out:
# Tools ready: ['get_room_map', 'get_witness_statement', 'get_evidence', 'get_weapons', 'get_rules']

# %% [markdown]
# ### Part 2 Structured Outputs

# %%
class HospitalEvidence(BaseModel):
    """Stage 1 output: all evidence gathered from the hospital."""
    rules: list[str]
    keycard_logs: list[str]
    witness_observations: list[str]
    suspect_statements: list[str]
    physical_evidence: list[str]
    weapons_info: str

class PuzzleSolution(BaseModel):
    """Stage 2 output: the final solution."""
    killer: str
    weapon: str
    time_of_death: str
    reasoning: str

# %% [markdown]
# ### TODO 4: Solve the Hospital Mystery
#
# Same two-stage pattern as Part 1: first gather all evidence, then deduce the answer.
#
# **Stage 1:** Write `instructions` for an evidence collector that uses ALL five tools to gather everything — room map, rules, keycard logs, physical evidence, weapons, and all four suspect statements.
#
# **Stage 2:** Write `instructions` for a solver that receives the evidence dossier and deduces the answer. No tools — just reasoning.

# %%
display_stage(1, "Evidence Collection", "Gathering all physical evidence, logs, and witness statements")
transcript = []  # Reset transcript for Part 2

evidence_collector = Agent(
    name="Evidence Collector",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions="""You are a forensic evidence collector investigating the murder of Dr. Eleanor Voss at St. Mercy Hospital. Your job is to gather ALL available evidence using every tool at your disposal. Be exhaustive — missing evidence means the analyst cannot solve the case.

Use ALL five tools in this order:
1. get_rules — Get the logical constraints for the investigation.
2. get_room_map — Get the hospital floor layout.
3. get_evidence — Get keycard access logs, physical evidence, and witness observations.
4. get_weapons — Get information about all potential murder weapons.
5. get_witness_statement for EACH of the four suspects:
   - get_witness_statement("dr_blake")
   - get_witness_statement("nurse_chen")
   - get_witness_statement("dr_santos")
   - get_witness_statement("orderly_james")

After collecting everything, organize your findings into the structured output:
- rules: All investigation rules/constraints
- keycard_logs: Every keycard access log entry
- witness_observations: All witness observations from the evidence
- suspect_statements: Each suspect's statement and motive
- physical_evidence: All physical evidence items
- weapons_info: Summary of all weapons and their details

Do not skip any tool. Do not skip any suspect. Every piece of evidence matters.""",  # TODO: Write your instructions here
    tools=hospital_tools,
    output_type=HospitalEvidence,
)

# Uncomment to run your agent:
collect_result = await Runner.run(evidence_collector, "Collect all evidence for the Dr. Voss murder case.", max_turns=15)
hospital_evidence = collect_result.final_output
# Out:
#     <div style="background:linear-gradient(90deg,#0d47a1,#1565c0,#1976d2);color:white;padding:12px 20px;border-radius:8px;margin:16px 0 8px 0;font-family:sans-serif;box-shadow:0 2px 6px rgba(0,0,0,0.2)">
#         <span style="background:rgba(255,255,255,0.2);padding:2px 10px;border-radius:12px;font-size:12px;font-weight:bold;margin-right:10px">STAGE 1</span>
#         <span style="font-size:16px;font-weight:bold">Evidence Collection</span>
#         <div style="color:#b0bec5;font-size:13px;margin-top:4px">Gathering all physical evidence, logs, and witness statements</div>
#     </div>
#     <div style="background:#37474f;color:#eceff1;padding:10px 14px;border-radius:8px;border-left:4px solid #80cbc4;margin:6px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:11px;color:#80cbc4;margin-bottom:4px">&#128483; WITNESS STATEMENT</div>
#         <b>Dr. Raymond Blake</b> <span style="color:#90a4ae">(Cardiologist, Dr. Voss's protégé)</span>
#         <div style="margin-top:4px;font-style:italic;color:#cfd8dc">"I was in the ER all evening covering for Dr. Santos who called in sick. I didn't go above the second floor all night. I heard about Dr. Voss this morning and I'm devastated — she was my mentor."</div>
#     </div>
#     <div style="background:#37474f;color:#eceff1;padding:10px 14px;border-radius:8px;border-left:4px solid #80cbc4;margin:6px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:11px;color:#80cbc4;margin-bottom:4px">&#128483; WITNESS STATEMENT</div>
#         <b>Victor James</b> <span style="color:#90a4ae">(Night orderly)</span>
#         <div style="margin-top:4px;font-style:italic;color:#cfd8dc">"I was doing my rounds — moving equipment, restocking supply closets. I was on Floor 1 from 8:00 to 9:00, Floor 2 from 9:00 to 10:00, and Floor 3 from 10:00 to 11:00. I never went to Floor 4 on Sunday night."</div>
#     </div>
#     <div style="background:#37474f;color:#eceff1;padding:10px 14px;border-radius:8px;border-left:4px solid #80cbc4;margin:6px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:11px;color:#80cbc4;margin-bottom:4px">&#128483; WITNESS STATEMENT</div>
#         <b>Dr. Maria Santos</b> <span style="color:#90a4ae">(Emergency Medicine physician)</span>
#         <div style="margin-top:4px;font-style:italic;color:#cfd8dc">"I called in sick Sunday but came back to the hospital around 8:30 PM because I forgot my laptop in my office on Floor 2. I grabbed it and left by 9:15 PM. The front desk can confirm I signed out."</div>
#     </div>
#     <div style="background:#37474f;color:#eceff1;padding:10px 14px;border-radius:8px;border-left:4px solid #80cbc4;margin:6px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:11px;color:#80cbc4;margin-bottom:4px">&#128483; WITNESS STATEMENT</div>
#         <b>Nurse Margaret Chen</b> <span style="color:#90a4ae">(Senior ICU Nurse)</span>
#         <div style="margin-top:4px;font-style:italic;color:#cfd8dc">"I was on the ICU floor (Floor 3) all night. I took my break at 9:00 PM in the third-floor break room and was back on the floor by 9:20 PM. I never went to Floor 4."</div>
#     </div>

# %%
# Checkpoint: see what evidence was collected (uncomment after running Stage 1)
display_notes("Evidence Collected", {
    f"Rules ({len(hospital_evidence.rules)})": hospital_evidence.rules,
    f"Keycard logs ({len(hospital_evidence.keycard_logs)})": hospital_evidence.keycard_logs,
    f"Witness observations ({len(hospital_evidence.witness_observations)})": hospital_evidence.witness_observations,
    f"Suspect statements ({len(hospital_evidence.suspect_statements)})": hospital_evidence.suspect_statements,
    f"Physical evidence ({len(hospital_evidence.physical_evidence)})": hospital_evidence.physical_evidence,
})
# Out:
#     <div style="background:#1a237e;color:#e0e0e0;padding:14px 18px;border-radius:8px;border-left:4px solid #42a5f5;margin:8px 0;font-family:sans-serif;font-size:13px">
#         <div style="font-size:14px;font-weight:bold;color:#90caf9;margin-bottom:6px">&#128221; Evidence Collected</div>
#         <div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Rules (5):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>The killer must have had physical access to Floor 4 around the time of death (9:00-10:00 PM).</li><li>The weapon must match the cause of death (lethal injection of potassium chloride).</li><li>Keycard logs cannot be faked — they are tamper-proof hardware records.</li><li>Each suspect's statement may contain lies, but witness observations and physical evidence do not lie.</li><li>The killer is one of the four suspects listed.</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Keycard logs (10):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>8:00 PM | Dr. Voss | Floor 4 (her office) (entry)</li><li>8:15 PM | Dr. Blake | Floor 1 (ER) (entry)</li><li>8:30 PM | Dr. Santos | Floor 1 (main entrance) (entry)</li><li>8:35 PM | Dr. Santos | Floor 2 (her office) (entry)</li><li>9:00 PM | Nurse Chen | Floor 3 (break room) (entry)</li><li>9:10 PM | Dr. Santos | Floor 1 (main entrance) (exit)</li><li>9:15 PM | Nurse Chen | Floor 3 (ICU) (entry)</li><li>9:25 PM | Dr. Blake | Floor 4 (entry)</li><li>9:45 PM | Dr. Blake | Floor 1 (ER) (entry)</li><li>10:00 PM | Victor James | Floor 3 (supply closet) (entry)</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Witness observations (4):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>Front desk security: Dr. Santos signed in at 8:30 PM and signed out at 9:10 PM. No one else signed in or out between 8 PM and 11 PM.</li><li>Nurse Patel (Floor 4): I saw someone in a white coat near Room 401 around 9:30 PM. I assumed it was Dr. Voss's colleague visiting. I didn't see their face clearly.</li><li>Dr. Kim (ER): Dr. Blake was in the ER with me most of the evening, but he stepped out for about 25 minutes sometime after 9 PM. He said he went to get coffee.</li><li>Cafeteria staff: The cafeteria closed at 8 PM Sunday. No one came for coffee after closing.</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Suspect statements (4):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>**Dr. Raymond Blake** (Cardiologist, Dr. Voss's protg)
# Motive: Dr. Voss discovered he was falsifying data in a major clinical trial. She confronted him Sunday afternoon and told him she would report him to the medical board Monday morning. His career, reputation, and freedom were at stake.
# Statement: "I was in the ER all evening covering for Dr. Santos who called in sick. I didn't go above the second floor all night. I heard about Dr. Voss this morning and I'm devastated — she was my mentor."</li><li>**Nurse Margaret Chen** (Senior ICU Nurse)
# Motive: Dr. Voss had filed a formal complaint about medication errors on Chen's shifts. Chen was facing a disciplinary hearing next week that could end her 20-year career.
# Statement: "I was on the ICU floor (Floor 3) all night. I took my break at 9:00 PM in the third-floor break room and was back on the floor by 9:20 PM. I never went to Floor 4."</li><li>**Dr. Maria Santos** (Emergency Medicine physician)
# Motive: Dr. Voss blocked her promotion to department head last year, citing 'lack of leadership qualities.' Santos was still angry about it.
# Statement: "I called in sick Sunday but came back to the hospital around 8:30 PM because I forgot my laptop in my office on Floor 2. I grabbed it and left by 9:15 PM. The front desk can confirm I signed out."</li><li>**Victor James** (Night orderly)
# Motive: Dr. Voss caught him stealing controlled substances from the pharmacy last month. She gave him a 'last chance' warning instead of reporting him, but he lived in fear she'd change her mind.
# Statement: "I was doing my rounds — moving equipment, restocking supply closets. I was on Floor 1 from 8:00 to 9:00, Floor 2 from 9:00 to 10:00, and Floor 3 from 10:00 to 11:00. I never went to Floor 4 on Sunday night."</li></ul></div><div style='margin:4px 0'><span style='color:#81d4fa;font-weight:bold'>Physical evidence (5):</span> <ul style="margin:2px 0 2px 16px;padding:0"><li>Syringe found in sharps container on Floor 4 — contains potassium chloride residue, wiped clean of fingerprints</li><li>Dr. Voss's office door was unlocked when found — she always locked it when working alone</li><li>Dr. Voss's computer shows she was drafting an email to the medical board about 'falsified trial data' at 9:15 PM — the email was never sent</li><li>Security camera on Floor 4 was 'undergoing maintenance' Sunday — no footage available</li><li>Dr. Blake's lab coat found in the Floor 4 laundry bin Monday morning, though he claims he never went to Floor 4</li></ul></div>
#     </div>

# %%
display_stage(2, "Forensic Analysis", "Deducing killer, weapon, and time of death from evidence")

# This formats Stage 1 output as text for the solver
evidence_dossier = f"""=== INVESTIGATION RULES ===
{chr(10).join('- ' + r for r in hospital_evidence.rules)}

=== KEYCARD ACCESS LOGS ===
{chr(10).join('- ' + l for l in hospital_evidence.keycard_logs)}

=== WITNESS OBSERVATIONS ===
{chr(10).join('- ' + w for w in hospital_evidence.witness_observations)}

=== SUSPECT STATEMENTS ===
{chr(10).join('- ' + s for s in hospital_evidence.suspect_statements)}

=== PHYSICAL EVIDENCE ===
{chr(10).join('- ' + e for e in hospital_evidence.physical_evidence)}

=== WEAPONS ===
{hospital_evidence.weapons_info}"""

solver = Agent(
    name="Forensic Analyst",
    model=AGENTS_MODEL,
    model_settings=SETTINGS,
    instructions="""You are a forensic analyst solving the murder of Dr. Eleanor Voss at St. Mercy Hospital. You must deduce three things: the killer, the weapon, and the time of death.

Follow this systematic reasoning process:

STEP 1 — Establish the rules: Read the investigation rules carefully. These are logical constraints that must all be satisfied by your solution.

STEP 2 — Analyze keycard logs: Keycard access logs are HARDWARE RECORDS and CANNOT be faked or tampered with. They are ground truth for who was where and when.

STEP 3 — Find the liar: Compare each suspect's statement against the keycard logs. If a suspect's statement contradicts what the keycard logs show, that suspect is LYING. The suspect whose statement is contradicted by the keycard logs is the killer.

STEP 4 — Determine the weapon: Match the available weapons against the victim's cause of death. The weapon must be consistent with how Dr. Voss died and the physical evidence found.

STEP 5 — Determine time of death: 
CRITICAL: A timestamp showing the victim was still ALIVE (e.g., drafting an email) is NOT the time of death — it is the last-known-alive time. The time of death must be LATER than any evidence of the victim being alive. Cross-reference three sources:
  (a) The killer's keycard entry to the victim's floor (when they arrived)
  (b) Witness observations of someone near the victim's room (when the killing occurred)  
  (c) The killer's keycard return to their original location (when they left)
The time of death is when the witness SAW someone at the victim's door, not when the victim was last active.

STEP 6 — Verify: Check that your solution satisfies ALL investigation rules. The time of death MUST be after 9:15 PM (victim was alive then) and must align with a direct witness sighting. If any rule is violated, revise.

Provide your final answer with:
- killer: The full name of the murderer
- weapon: The specific murder weapon
- time_of_death: The specific time (from witness observation)
- reasoning: A clear chain of logic showing how the evidence proves your conclusion""",  # TODO: Write your instructions here
    output_type=PuzzleSolution,
)

# Uncomment to run your agent:
solve_result = await Runner.run(solver, f"Analyze this evidence and solve the murder:\n\n{evidence_dossier}", max_turns=3)
solution = solve_result.final_output
# Out:
#     <div style="background:linear-gradient(90deg,#0d47a1,#1565c0,#1976d2);color:white;padding:12px 20px;border-radius:8px;margin:16px 0 8px 0;font-family:sans-serif;box-shadow:0 2px 6px rgba(0,0,0,0.2)">
#         <span style="background:rgba(255,255,255,0.2);padding:2px 10px;border-radius:12px;font-size:12px;font-weight:bold;margin-right:10px">STAGE 2</span>
#         <span style="font-size:16px;font-weight:bold">Forensic Analysis</span>
#         <div style="color:#b0bec5;font-size:13px;margin-top:4px">Deducing killer, weapon, and time of death from evidence</div>
#     </div>

# %%
# Uncomment to see the verdict:
display_verdict("SOLUTION", {
    "Killer": solution.killer,
    "Weapon": solution.weapon,
    "Time of Death": solution.time_of_death,
    "Reasoning": solution.reasoning,
})
# Out:
#     <div style="background:linear-gradient(135deg,#1a1a2e,#0d1117);color:#e0e0e0;padding:20px 24px;border-radius:10px;border-left:5px solid #c62828;font-family:Georgia,serif;margin:16px 0;box-shadow:0 2px 8px rgba(0,0,0,0.3)">
#         <div style="font-size:18px;font-weight:bold;color:#ff8a80;margin-bottom:10px;letter-spacing:1px">&#9878; SOLUTION</div>
#         <table style="border-collapse:collapse"><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Killer</td><td style='padding:6px 14px;color:#e0e0e0'>Dr. Raymond Blake</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Weapon</td><td style='padding:6px 14px;color:#e0e0e0'>Syringe</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Time of Death</td><td style='padding:6px 14px;color:#e0e0e0'>9:30 PM</td></tr><tr><td style='padding:6px 14px;color:#ffab91;font-weight:bold;vertical-align:top;white-space:nowrap'>Reasoning</td><td style='padding:6px 14px;color:#e0e0e0'>Dr. Blake is the killer because his statement contradicts the keycard logs. He claimed to be in the ER all evening, but the logs show he entered Floor 4 at 9:25 PM, which means he was not in the ER as he stated. The weapon used was a syringe containing potassium chloride, which matches the cause of death. The time of death is determined to be 9:30 PM, as Nurse Patel saw someone in a white coat near Room 401 at that time, and Dr. Blake's keycard entry to Floor 4 supports that he was there shortly before the witness sighting.</td></tr></table>
#     </div>

# %% [markdown]
# **Checkpoint:** The test checks killer, weapon, AND time of death. If any are wrong, print `evidence_dossier` to see what the solver received. Key hints for your solver instructions:
# - Keycard logs are hardware records — they CANNOT be faked
# - Compare each suspect's statement against the keycard logs — the liar is the killer
# - Match the weapon to the cause of death
# - Time of death comes from a **witness observation** (what someone saw and when), NOT from the victim's last email
#
# ### Save Part 2 Results

# %%
part2_results = {
    "killer": solution.killer,
    "weapon": solution.weapon,
    "time_of_death": solution.time_of_death,
    "reasoning": solution.reasoning,
    "transcript": transcript,
}

with open("output/part2_results.json", "w") as f:
    json.dump(part2_results, f, indent=2)

print(f"Saved to output/part2_results.json ({len(transcript)} transcript entries)")
# Out:
# Saved to output/part2_results.json (8 transcript entries)

# %% [markdown]
# ---
#
# # Validation
#
# Run the tests to check your results:

# %%
# !python -m pytest .github/tests/ -v

# %% [markdown]
# ---
#
# # Interactive Interrogation (Optional)
#
# Use the interactive detective to manually explore the cabin mystery. This is helpful for understanding the mystery before writing agent instructions, or for debugging when your agents get the wrong answer.

# %%
print("=== Interactive Detective Mode ===")
print("Tell the detective who to interrogate or where to search.")
print("Examples: 'Ask Diana about her alibi', 'Search the kitchen'")
print("Type 'q' to exit.\n")

try:
    while True:
        user_input = input('Detective ("q" to quit)> ').strip()
        if user_input.lower() in ("quit", "exit", "q"):
            print("Case closed.")
            break
        if not user_input:
            continue
        result = await Runner.run(interactive_detective, user_input)
        print(f"\n{result.final_output}\n")
except (EOFError, KeyboardInterrupt):
    print("\nCase closed.")
except Exception:
    print("(Interactive mode requires a live notebook — skipping in headless execution.)")
# Out:
# === Interactive Detective Mode ===
# Tell the detective who to interrogate or where to search.
# Examples: 'Ask Diana about her alibi', 'Search the kitchen'
# Type 'q' to exit.
#
# Case closed.
